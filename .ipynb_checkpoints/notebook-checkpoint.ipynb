# %% [markdown]
# # Predictive Maintenance - Classifying whether a machine will fail within the next 7 days
#
# ### Author : Kelvin Kipkorir
#
# ![Predictive Maintenance Overview](images/overview.jpg)

# %% [markdown]
# # Overview
# ****
# Predictive maintenance is a strategy that anticipates failures in industrial machinery before they occur. Unlike traditional maintenance practices, which often involve scheduled servicing or reacting to breakdowns, predictive maintenance enables industries to perform maintenance only when it's truly needed.
#
# Traditional maintenance strategies typically fall into two categories:
#
# 1. `Run-to-Failure` – The machine is used until it breaks down, after which it is either repaired or replaced.
# 2. `Preventive Maintenance` – Maintenance is performed at regular, scheduled intervals, regardless of the machine’s actual condition.
#
# With the development of microprocessors and advancements in machine learning (ML), predictive maintenance has become increasingly practical and effective. Unlike physics-based models, ML models can handle **large-scale, high-dimensional datasets**, making them well-suited for analyzing sensor readings and operational metrics. These models have revolutionized the estimation of **Remaining Useful Life (RUL)** for industrial systems and play a critical role in minimizing costly downtime caused by unexpected failures.
#
# This project aims to support **TechLine Industries** in adopting predictive maintenance across their smart factory operations. By leveraging machine learning — specifically **logistic regression** and **decision trees** — the project classifies whether a machine is likely to fail within the next 7 days.

# %% [markdown]
# # Business Problem
# ****
# Techline Industries is a growing manufacturing company that has numerous machines in its manufacturing plants. As part of its digital transformation strategy, the company is investing in predictive maintenance to reduce operational costs, minimize unplanned downtime, and improve equipment reliability. However, with complex sensor data being generated across various machine types, the company lacks a robust system to anticipate failures before they occur.
#
# To address this challenge, historical sensor data will be used to develop a machine learning model that can predict equipment failures up to one week in advance. This will empower maintenance teams to take timely, corrective actions — helping the company avoid costly downtimes typically associated with traditional maintenance strategies.

# %% [markdown]
# # Objectives
# ****
# The main objective of this project is to develop a machine learning model that predicts whether a machine is likely to fail within the next 7 days, using sensor and operational data. To achieve this, the following specific objectives will be pursued:
#
# 1. **Explore and Understand the Dataset**
#    Analyze the structure, content, and distribution of the dataset to gain insights into the key variables and relationships that may affect machine failures.
#
# 2. **Preprocess the Data for Modeling**
#    Clean and transform the data to ensure it is suitable for machine learning, including handling missing values, encoding categorical features, and balancing the classes.
#
# 3. **Build and Evaluate Baseline Classification Models**
#    Implement basic models such as logistic regression and decision trees to establish performance benchmarks.
#
# 4. **Perform Hyperparameter Tuning**
#    Optimize model performance through parameter tuning using techniques like grid search or cross-validation.
#
# 5. **Compare Model Performances**
#    Evaluate and compare models using metrics such as accuracy, precision, recall, F1-score, and AUC-ROC to determine the best approach.
#
# 6. **Draw Business Insights and Recommendations**
#    Interpret the results to provide actionable insights for TechLine Industries, enabling them to reduce downtime and improve equipment reliability through predictive maintenance.

# %% [markdown]
# # Data Understanding
#
# The dataset used in this project, sourced from Kaggle and titled **"Industrial IoT"**, contains **500,000 entries** representing various operational conditions of industrial machines. It includes **22 columns** capturing both sensor readings and metadata, such as temperature, vibration, pressure, coolant flow, and installation year. These features simulate real-world telemetry data from Industrial IoT systems, providing a good foundation for developing predictive maintenance models.

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
#importing standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#extract data from the zip file 
df = pd.read_csv('industrial_iot_data.zip', compression='zip')
df
# Out:
#        Machine_ID        Machine_Type  Installation_Year  Operational_Hours  \
# 0       MC_000000               Mixer               2027              81769
# 1       MC_000001  Industrial_Chiller               2032              74966
# 2       MC_000002      Pick_and_Place               2003              94006
# 3       MC_000003       Vision_System               2007              76637
# 4       MC_000004      Shuttle_System               2016              20870
# ...           ...                 ...                ...                ...
# 499995  MC_499995       Vacuum_Packer               2011              14425
# 499996  MC_499996       Conveyor_Belt               2003              75501
# 499997  MC_499997                 CMM               2039              19855
# 499998  MC_499998               Dryer               2035              86823
# 499999  MC_499999  Industrial_Chiller               2021              52505
#
#         Temperature_C  Vibration_mms  Sound_dB  Oil_Level_pct  \
# 0               73.43          12.78     83.72          36.76
# 1               58.32          14.99     77.04         100.00
# 2               49.63          23.78     69.08          42.96
# 3               63.73          12.38     85.58          94.90
# 4               42.77           4.42     96.72          47.56
# ...               ...            ...       ...            ...
# 499995          65.42          16.50     81.95          59.21
# 499996          44.83          12.88     64.94          73.69
# 499997          37.26          11.46     70.70          70.70
# 499998          67.72          16.76     77.45          97.00
# 499999          46.01           8.94     67.88          51.11
#
#         Coolant_Level_pct  Power_Consumption_kW  ...  Failure_History_Count  \
# 0                   68.74                 84.95  ...                      5
# 1                   62.13                154.61  ...                      2
# 2                   35.96                 51.90  ...                      1
# 3                   48.94                 75.61  ...                      1
# 4                   53.78                224.93  ...                      2
# ...                   ...                   ...  ...                    ...
# 499995              73.67                255.87  ...                      3
# 499996              29.25                198.37  ...                      1
# 499997              49.04                156.59  ...                      2
# 499998              15.40                132.33  ...                      2
# 499999              31.90                138.69  ...                      1
#
#         AI_Supervision  Error_Codes_Last_30_Days  Remaining_Useful_Life_days  \
# 0                 True                         3                       162.0
# 1                 True                         4                       147.0
# 2                 True                         6                         0.0
# 3                False                         4                       161.0
# 4                False                         1                       765.0
# ...                ...                       ...                         ...
# 499995           False                         0                       820.0
# 499996           False                         4                        34.0
# 499997           False                         4                       815.0
# 499998            True                         0                        99.0
# 499999           False                         4                       489.0
#
#         Failure_Within_7_Days  Laser_Intensity  Hydraulic_Pressure_bar  \
# 0                       False              NaN                     NaN
# 1                       False              NaN                     NaN
# 2                        True              NaN                     NaN
# 3                       False              NaN                     NaN
# 4                       False              NaN                     NaN
# ...                       ...              ...                     ...
# 499995                  False              NaN                     NaN
# 499996                  False              NaN                     NaN
# 499997                  False              NaN                     NaN
# 499998                  False              NaN                     NaN
# 499999                  False              NaN                     NaN
#
#         Coolant_Flow_L_min  Heat_Index  AI_Override_Events
# 0                      NaN         NaN                   2
# 1                    40.92         NaN                   2
# 2                      NaN         NaN                   2
# 3                      NaN         NaN                   0
# 4                      NaN         NaN                   0
# ...                    ...         ...                 ...
# 499995                 NaN         NaN                   0
# 499996                 NaN         NaN                   0
# 499997                 NaN         NaN                   0
# 499998                 NaN         NaN                   2
# 499999               41.09         NaN                   0
#
# [500000 rows x 22 columns]

# %%
#look at the columns and if there any missing values
df.info()
print("The dataset shape : {}".format(df.shape))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Machine_ID                  500000 non-null  object
#  1   Machine_Type                500000 non-null  object
#  2   Installation_Year           500000 non-null  int64
#  3   Operational_Hours           500000 non-null  int64
#  4   Temperature_C               500000 non-null  float64
#  5   Vibration_mms               500000 non-null  float64
#  6   Sound_dB                    500000 non-null  float64
#  7   Oil_Level_pct               500000 non-null  float64
#  8   Coolant_Level_pct           500000 non-null  float64
#  9   Power_Consumption_kW        500000 non-null  float64
#  10  Last_Maintenance_Days_Ago   500000 non-null  int64
#  11  Maintenance_History_Count   500000 non-null  int64
#  12  Failure_History_Count       500000 non-null  int64
#  13  AI_Supervision              500000 non-null  bool
#  14  Error_Codes_Last_30_Days    500000 non-null  int64
#  15  Remaining_Useful_Life_days  500000 non-null  float64
#  16  Failure_Within_7_Days       500000 non-null  bool
#  17  Laser_Intensity             15156 non-null   float64
#  18  Hydraulic_Pressure_bar      30340 non-null   float64
#  19  Coolant_Flow_L_min          45624 non-null   float64
#  20  Heat_Index                  45214 non-null   float64
#  21  AI_Override_Events          500000 non-null  int64
# dtypes: bool(2), float64(11), int64(7), object(2)
# memory usage: 77.2+ MB
# The dataset shape : (500000, 22)

# %%
# looking at the amount of missing values
df.isna().sum()
# Out:
# Machine_ID                         0
# Machine_Type                       0
# Installation_Year                  0
# Operational_Hours                  0
# Temperature_C                      0
# Vibration_mms                      0
# Sound_dB                           0
# Oil_Level_pct                      0
# Coolant_Level_pct                  0
# Power_Consumption_kW               0
# Last_Maintenance_Days_Ago          0
# Maintenance_History_Count          0
# Failure_History_Count              0
# AI_Supervision                     0
# Error_Codes_Last_30_Days           0
# Remaining_Useful_Life_days         0
# Failure_Within_7_Days              0
# Laser_Intensity               484844
# Hydraulic_Pressure_bar        469660
# Coolant_Flow_L_min            454376
# Heat_Index                    454786
# AI_Override_Events                 0
# dtype: int64

# %% [markdown]
# The `Laser_Intesity`,`Hydraulic_Pressure_bar`,`Coolant_Flow_L_min`,`Heat_Index` have a lot of missing values

# %%
# Visulize the distribution of the remaining useful days(RUL)
sns.histplot(df["Remaining_Useful_Life_days"], bins=70, kde=True)
plt.title('Distribution RUL')
plt.xlabel("Days")
plt.ylabel("Machine Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#the distribution of the target feature
print(df['Failure_Within_7_Days'].value_counts())

plt.figure(figsize=(5, 3))
sns.countplot(x="Failure_Within_7_Days", data=df)
plt.title("Failure Within 7 Days Distribution")
plt.xlabel("Failure")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# False    469968
# True      30032
# Name: Failure_Within_7_Days, dtype: int64

# %% [markdown]
# ##### There are 469968 machines that will not fail in the next 7 days and 30032 that will likely fail in next seven days.
# The data displays class **imbalance** problems
#
# *****

# %% [markdown]
# #### Visualizing correlations in numeric variables

# %%
# Correlation heatmap for numeric features
num_features = df.select_dtypes(include=[np.number])
if "Failure_Within_7_Days" in num_features.columns:
    num_features = num_features.drop(columns=["Failure_Within_7_Days"])
plt.figure(figsize=(14, 10))
sns.heatmap(num_features.corr(), cmap="Blues", center=0, annot=False)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ----
# There is a negative correlation between remaining useful life and operational hours

# %% [markdown]
# #### Since there different types of machines it is also helpful to visualize failure by machine type

# %%
#see the type of machines in the industry
print(f"There are {len(df['Machine_Type'].value_counts())} machine types")

# Failure rate by machine type
failure_by_type = df.groupby("Machine_Type")["Failure_Within_7_Days"].mean().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
failure_by_type.plot(kind="bar", color="blue")
plt.title("Failure Rate by Machine Type")
plt.ylabel("Failure Probability")
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# There are 33 machine types

# %% [markdown]
# ## 2. Data Preprocessing
#
# To ensure the dataset was suitable for machine learning models, several preprocessing steps were carried out:
#
# - **Handling Missing Values**: Numerical columns with missing values were imputed using `SimpleImputer`. Additionally, `MissingIndicator` was used to flag the presence of missing values as separate features, preserving any potential signal from missingness patterns.
#
# - **Categorical Encoding**: The `machine_type` feature, which contains 33 unique categories, was transformed using `OneHotEncoder` to allow models to interpret the categorical data numerically.
#
# - **Feature Scaling**: Numerical features were standardized to have zero mean and unit variance using `StandardScaler`, which is especially beneficial for models like Logistic Regression.
#
# - **Class Imbalance Handling**: The target variable was highly imbalanced, with far fewer failure instances. To address this, **SMOTE (Synthetic Minority Over-sampling Technique)** was applied to the training data to generate synthetic samples for the minority class, helping models learn more balanced decision boundaries.

# %% [markdown]
# #### Lets look at the columns and see if there are any we can drop because of alot of missing values

# %%
# Drop columns with more than 90% missing
threshold = 0.9
missing_fraction = df.isnull().mean()
columns_to_consider_droping = missing_fraction[missing_fraction > threshold].index
print(columns_to_consider_droping)
# Out:
# Index(['Laser_Intensity', 'Hydraulic_Pressure_bar', 'Coolant_Flow_L_min',
#        'Heat_Index'],
#       dtype='object')

# %% [markdown]
# Now that we see that these 4 columns have lots of missing values we can try and see what they contain by grouping data using them. Sometimes certain Features can be specific to machines and don't apply to other machines

# %%
df.groupby('Machine_Type')[['Laser_Intensity', 'Hydraulic_Pressure_bar', 'Coolant_Flow_L_min', 'Heat_Index']].count()
# Out:
#                        Laser_Intensity  Hydraulic_Pressure_bar  \
# Machine_Type
# 3D_Printer                           0                       0
# AGV                                  0                       0
# Automated_Screwdriver                0                       0
# Boiler                               0                       0
# CMM                                  0                       0
# CNC_Lathe                            0                       0
# CNC_Mill                             0                       0
# Carton_Former                        0                       0
# Compressor                           0                       0
# Conveyor_Belt                        0                       0
# Crane                                0                       0
# Dryer                                0                       0
# Forklift_Electric                    0                       0
# Furnace                              0                       0
# Grinder                              0                       0
# Heat_Exchanger                       0                       0
# Hydraulic_Press                      0                   15124
# Industrial_Chiller                   0                       0
# Injection_Molder                     0                   15216
# Labeler                              0                       0
# Laser_Cutter                     15156                       0
# Mixer                                0                       0
# Palletizer                           0                       0
# Pick_and_Place                       0                       0
# Press_Brake                          0                       0
# Pump                                 0                       0
# Robot_Arm                            0                       0
# Shrink_Wrapper                       0                       0
# Shuttle_System                       0                       0
# Vacuum_Packer                        0                       0
# Valve_Controller                     0                       0
# Vision_System                        0                       0
# XRay_Inspector                       0                       0
#
#                        Coolant_Flow_L_min  Heat_Index
# Machine_Type
# 3D_Printer                              0           0
# AGV                                     0           0
# Automated_Screwdriver                   0           0
# Boiler                                  0       15050
# CMM                                     0           0
# CNC_Lathe                           15290           0
# CNC_Mill                            15064           0
# Carton_Former                           0           0
# Compressor                              0           0
# Conveyor_Belt                           0           0
# Crane                                   0           0
# Dryer                                   0           0
# Forklift_Electric                       0           0
# Furnace                                 0       15027
# Grinder                                 0           0
# Heat_Exchanger                          0       15137
# Hydraulic_Press                         0           0
# Industrial_Chiller                  15270           0
# Injection_Molder                        0           0
# Labeler                                 0           0
# Laser_Cutter                            0           0
# Mixer                                   0           0
# Palletizer                              0           0
# Pick_and_Place                          0           0
# Press_Brake                             0           0
# Pump                                    0           0
# Robot_Arm                               0           0
# Shrink_Wrapper                          0           0
# Shuttle_System                          0           0
# Vacuum_Packer                           0           0
# Valve_Controller                        0           0
# Vision_System                           0           0
# XRay_Inspector                          0           0

# %% [markdown]
# As we can see the features are specific to some machines So for all other machines we will impute values of 0 in each of the features

# %% [markdown]
# Looking at the dataset we have the installation year. A better feature to use will be the machine age. The dataset has years upto `2040`. We will use the `2040` as the current year so that we are able to calculate `machine age` withouth gettig negative ages

# %%
#Feature engineering the age column
current_year = df["Installation_Year"].max()
df["Machine_Age"] = current_year - df["Installation_Year"]
df.drop('Installation_Year',axis=1,inplace=True)
df
# Out:
#        Machine_ID        Machine_Type  Operational_Hours  Temperature_C  \
# 0       MC_000000               Mixer              81769          73.43
# 1       MC_000001  Industrial_Chiller              74966          58.32
# 2       MC_000002      Pick_and_Place              94006          49.63
# 3       MC_000003       Vision_System              76637          63.73
# 4       MC_000004      Shuttle_System              20870          42.77
# ...           ...                 ...                ...            ...
# 499995  MC_499995       Vacuum_Packer              14425          65.42
# 499996  MC_499996       Conveyor_Belt              75501          44.83
# 499997  MC_499997                 CMM              19855          37.26
# 499998  MC_499998               Dryer              86823          67.72
# 499999  MC_499999  Industrial_Chiller              52505          46.01
#
#         Vibration_mms  Sound_dB  Oil_Level_pct  Coolant_Level_pct  \
# 0               12.78     83.72          36.76              68.74
# 1               14.99     77.04         100.00              62.13
# 2               23.78     69.08          42.96              35.96
# 3               12.38     85.58          94.90              48.94
# 4                4.42     96.72          47.56              53.78
# ...               ...       ...            ...                ...
# 499995          16.50     81.95          59.21              73.67
# 499996          12.88     64.94          73.69              29.25
# 499997          11.46     70.70          70.70              49.04
# 499998          16.76     77.45          97.00              15.40
# 499999           8.94     67.88          51.11              31.90
#
#         Power_Consumption_kW  Last_Maintenance_Days_Ago  ...  AI_Supervision  \
# 0                      84.95                        153  ...            True
# 1                     154.61                        136  ...            True
# 2                      51.90                        258  ...            True
# 3                      75.61                         43  ...           False
# 4                     224.93                        346  ...           False
# ...                      ...                        ...  ...             ...
# 499995                255.87                        282  ...           False
# 499996                198.37                        208  ...           False
# 499997                156.59                        185  ...           False
# 499998                132.33                        274  ...            True
# 499999                138.69                        171  ...           False
#
#         Error_Codes_Last_30_Days  Remaining_Useful_Life_days  \
# 0                              3                       162.0
# 1                              4                       147.0
# 2                              6                         0.0
# 3                              4                       161.0
# 4                              1                       765.0
# ...                          ...                         ...
# 499995                         0                       820.0
# 499996                         4                        34.0
# 499997                         4                       815.0
# 499998                         0                        99.0
# 499999                         4                       489.0
#
#         Failure_Within_7_Days  Laser_Intensity  Hydraulic_Pressure_bar  \
# 0                       False              NaN                     NaN
# 1                       False              NaN                     NaN
# 2                        True              NaN                     NaN
# 3                       False              NaN                     NaN
# 4                       False              NaN                     NaN
# ...                       ...              ...                     ...
# 499995                  False              NaN                     NaN
# 499996                  False              NaN                     NaN
# 499997                  False              NaN                     NaN
# 499998                  False              NaN                     NaN
# 499999                  False              NaN                     NaN
#
#         Coolant_Flow_L_min  Heat_Index  AI_Override_Events  Machine_Age
# 0                      NaN         NaN                   2           13
# 1                    40.92         NaN                   2            8
# 2                      NaN         NaN                   2           37
# 3                      NaN         NaN                   0           33
# 4                      NaN         NaN                   0           24
# ...                    ...         ...                 ...          ...
# 499995                 NaN         NaN                   0           29
# 499996                 NaN         NaN                   0           37
# 499997                 NaN         NaN                   0            1
# 499998                 NaN         NaN                   2            5
# 499999               41.09         NaN                   0           19
#
# [500000 rows x 22 columns]

# %%
#visualize the machine type using a histogram
sns.histplot(df["Machine_Age"], bins=20)
plt.title('Age of machine')
plt.xlabel("years")
plt.ylabel("Machine Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# change the AI supervision column to be int type
df['AI_Supervision'] = df['AI_Supervision'].astype(int)

# %% [markdown]
# #### Split your dataset into X and y
# Our target feature is `Failure_Within_7_days`
# For X we  drop the the target feature and also the machine ID as it is just an identification data

# %%
# split the dataframe to x and y
X = df.drop(['Failure_Within_7_Days','Machine_ID'],axis = 1)
y = df['Failure_Within_7_Days'].astype(int)

# %% [markdown]
# To avoid data leakage we first split our data into the train and test categories. `stratify = y` helps to make sure that the class weights in the split datasets are propotional to those in the original.
#
# The split ratio used in this case is 75/25 for the train/test sets

# %%
from sklearn.model_selection import train_test_split

#split you data into  train and test samples
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state = 42,stratify=y)

# %% [markdown]
# There are 33 machine types in this dataset. We will be using **OneHotEncoder** to convert this categorical column into a numerical.

# %%
from sklearn.preprocessing import OneHotEncoder

categorical_features = ['Machine_Type']

encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)

# fit_transform training data
X_train_encoded = encoder.fit_transform(X_train[categorical_features])

# transform test data 
X_test_encoded = encoder.transform(X_test[categorical_features])

encoded_feature_names = encoder.get_feature_names(categorical_features)

X_train_encoded_df = pd.DataFrame(X_train_encoded, columns=encoded_feature_names, index=X_train.index)
X_test_encoded_df = pd.DataFrame(X_test_encoded, columns=encoded_feature_names, index=X_test.index)

# preview
X_train_encoded_df
# Out:
#         Machine_Type_3D_Printer  Machine_Type_AGV  \
# 11509                       0.0               0.0
# 238921                      0.0               0.0
# 272103                      0.0               0.0
# 60521                       0.0               0.0
# 71915                       0.0               0.0
# ...                         ...               ...
# 80107                       0.0               0.0
# 409670                      0.0               0.0
# 400693                      0.0               0.0
# 311254                      0.0               0.0
# 264173                      0.0               0.0
#
#         Machine_Type_Automated_Screwdriver  Machine_Type_Boiler  \
# 11509                                  0.0                  0.0
# 238921                                 0.0                  0.0
# 272103                                 0.0                  0.0
# 60521                                  0.0                  0.0
# 71915                                  0.0                  0.0
# ...                                    ...                  ...
# 80107                                  0.0                  0.0
# 409670                                 0.0                  0.0
# 400693                                 0.0                  0.0
# 311254                                 0.0                  0.0
# 264173                                 0.0                  0.0
#
#         Machine_Type_CMM  Machine_Type_CNC_Lathe  Machine_Type_CNC_Mill  \
# 11509                0.0                     0.0                    1.0
# 238921               0.0                     0.0                    0.0
# 272103               0.0                     0.0                    1.0
# 60521                0.0                     0.0                    0.0
# 71915                0.0                     0.0                    0.0
# ...                  ...                     ...                    ...
# 80107                0.0                     0.0                    0.0
# 409670               0.0                     0.0                    0.0
# 400693               0.0                     1.0                    0.0
# 311254               0.0                     0.0                    0.0
# 264173               0.0                     0.0                    0.0
#
#         Machine_Type_Carton_Former  Machine_Type_Compressor  \
# 11509                          0.0                      0.0
# 238921                         0.0                      0.0
# 272103                         0.0                      0.0
# 60521                          0.0                      0.0
# 71915                          0.0                      0.0
# ...                            ...                      ...
# 80107                          0.0                      0.0
# 409670                         0.0                      0.0
# 400693                         0.0                      0.0
# 311254                         0.0                      0.0
# 264173                         0.0                      0.0
#
#         Machine_Type_Conveyor_Belt  ...  Machine_Type_Pick_and_Place  \
# 11509                          0.0  ...                          0.0
# 238921                         0.0  ...                          0.0
# 272103                         0.0  ...                          0.0
# 60521                          0.0  ...                          0.0
# 71915                          0.0  ...                          0.0
# ...                            ...  ...                          ...
# 80107                          0.0  ...                          0.0
# 409670                         0.0  ...                          0.0
# 400693                         0.0  ...                          0.0
# 311254                         0.0  ...                          0.0
# 264173                         0.0  ...                          0.0
#
#         Machine_Type_Press_Brake  Machine_Type_Pump  Machine_Type_Robot_Arm  \
# 11509                        0.0                0.0                     0.0
# 238921                       0.0                0.0                     0.0
# 272103                       0.0                0.0                     0.0
# 60521                        0.0                0.0                     0.0
# 71915                        0.0                0.0                     0.0
# ...                          ...                ...                     ...
# 80107                        0.0                0.0                     1.0
# 409670                       0.0                0.0                     0.0
# 400693                       0.0                0.0                     0.0
# 311254                       0.0                0.0                     0.0
# 264173                       1.0                0.0                     0.0
#
#         Machine_Type_Shrink_Wrapper  Machine_Type_Shuttle_System  \
# 11509                           0.0                          0.0
# 238921                          0.0                          0.0
# 272103                          0.0                          0.0
# 60521                           0.0                          0.0
# 71915                           0.0                          0.0
# ...                             ...                          ...
# 80107                           0.0                          0.0
# 409670                          0.0                          0.0
# 400693                          0.0                          0.0
# 311254                          0.0                          0.0
# 264173                          0.0                          0.0
#
#         Machine_Type_Vacuum_Packer  Machine_Type_Valve_Controller  \
# 11509                          0.0                            0.0
# 238921                         0.0                            0.0
# 272103                         0.0                            0.0
# 60521                          0.0                            0.0
# 71915                          0.0                            0.0
# ...                            ...                            ...
# 80107                          0.0                            0.0
# 409670                         0.0                            0.0
# 400693                         0.0                            0.0
# 311254                         0.0                            0.0
# 264173                         0.0                            0.0
#
#         Machine_Type_Vision_System  Machine_Type_XRay_Inspector
# 11509                          0.0                          0.0
# 238921                         0.0                          0.0
# 272103                         0.0                          0.0
# 60521                          0.0                          0.0
# 71915                          0.0                          0.0
# ...                            ...                          ...
# 80107                          0.0                          0.0
# 409670                         0.0                          0.0
# 400693                         0.0                          0.0
# 311254                         1.0                          0.0
# 264173                         0.0                          0.0
#
# [375000 rows x 33 columns]

# %% [markdown]
# We drop the hot encoded column and concatenate the encoded columns

# %%
# Drop original
X_train = X_train.drop(columns=categorical_features,axis=1)
X_test = X_test.drop(columns=categorical_features,axis=1)

# Concatenate encoded columns
X_train = pd.concat([X_train, X_train_encoded_df], axis=1)
X_test = pd.concat([X_test, X_test_encoded_df], axis=1)

# %%
X_train.head(4)
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 375000 entries, 11509 to 264173
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Operational_Hours                   375000 non-null  int64
#  1   Temperature_C                       375000 non-null  float64
#  2   Vibration_mms                       375000 non-null  float64
#  3   Sound_dB                            375000 non-null  float64
#  4   Oil_Level_pct                       375000 non-null  float64
#  5   Coolant_Level_pct                   375000 non-null  float64
#  6   Power_Consumption_kW                375000 non-null  float64
#  7   Last_Maintenance_Days_Ago           375000 non-null  int64
#  8   Maintenance_History_Count           375000 non-null  int64
#  9   Failure_History_Count               375000 non-null  int64
#  10  AI_Supervision                      375000 non-null  int32
#  11  Error_Codes_Last_30_Days            375000 non-null  int64
#  12  Remaining_Useful_Life_days          375000 non-null  float64
#  13  Laser_Intensity                     11408 non-null   float64
#  14  Hydraulic_Pressure_bar              22750 non-null   float64
#  15  Coolant_Flow_L_min                  34190 non-null   float64
#  16  Heat_Index                          33992 non-null   float64
#  17  AI_Override_Events                  375000 non-null  int64
#  18  Machine_Age                         375000 non-null  int64
#  19  Machine_Type_3D_Printer             375000 non-null  float64
#  20  Machine_Type_AGV                    375000 non-null  float64
#  21  Machine_Type_Automated_Screwdriver  375000 non-null  float64
#  22  Machine_Type_Boiler                 375000 non-null  float64
#  23  Machine_Type_CMM                    375000 non-null  float64
#  24  Machine_Type_CNC_Lathe              375000 non-null  float64
#  25  Machine_Type_CNC_Mill               375000 non-null  float64
#  26  Machine_Type_Carton_Former          375000 non-null  float64
#  27  Machine_Type_Compressor             375000 non-null  float64
#  28  Machine_Type_Conveyor_Belt          375000 non-null  float64
#  29  Machine_Type_Crane                  375000 non-null  float64
#  30  Machine_Type_Dryer                  375000 non-null  float64
#  31  Machine_Type_Forklift_Electric      375000 non-null  float64
#  32  Machine_Type_Furnace                375000 non-null  float64
#  33  Machine_Type_Grinder                375000 non-null  float64
#  34  Machine_Type_Heat_Exchanger         375000 non-null  float64
#  35  Machine_Type_Hydraulic_Press        375000 non-null  float64
#  36  Machine_Type_Industrial_Chiller     375000 non-null  float64
#  37  Machine_Type_Injection_Molder       375000 non-null  float64
#  38  Machine_Type_Labeler                375000 non-null  float64
#  39  Machine_Type_Laser_Cutter           375000 non-null  float64
#  40  Machine_Type_Mixer                  375000 non-null  float64
#  41  Machine_Type_Palletizer             375000 non-null  float64
#  42  Machine_Type_Pick_and_Place         375000 non-null  float64
#  43  Machine_Type_Press_Brake            375000 non-null  float64
#  44  Machine_Type_Pump                   375000 non-null  float64
#  45  Machine_Type_Robot_Arm              375000 non-null  float64
#  46  Machine_Type_Shrink_Wrapper         375000 non-null  float64
#  47  Machine_Type_Shuttle_System         375000 non-null  float64
#  48  Machine_Type_Vacuum_Packer          375000 non-null  float64
#  49  Machine_Type_Valve_Controller       375000 non-null  float64
#  50  Machine_Type_Vision_System          375000 non-null  float64
#  51  Machine_Type_XRay_Inspector         375000 non-null  float64
# dtypes: float64(44), int32(1), int64(7)
# memory usage: 150.2 MB

# %% [markdown]
# The **MissingIndicator** is used to show whether a value contained a null value in the original dataset.

# %%
#adding missing indicators
from sklearn.impute import MissingIndicator

columns_to_be_imputed_train = X_train[['Laser_Intensity', 'Hydraulic_Pressure_bar', 'Coolant_Flow_L_min', 'Heat_Index']]
columns_to_be_imputed_test = X_test[['Laser_Intensity', 'Hydraulic_Pressure_bar', 'Coolant_Flow_L_min', 'Heat_Index']]

indicator = MissingIndicator()
X_train_indicators = indicator.fit_transform(columns_to_be_imputed_train)
X_test_indicators = indicator.transform(columns_to_be_imputed_test)

#create column names for indicators
indicator_columns = [col + "_Missing" for col in columns_to_be_imputed_train.columns]

#numpy arrays to a DataFrame
X_train_indicators_df = pd.DataFrame(X_train_indicators.astype(int), columns=indicator_columns, index=X_train.index)
X_test_indicators_df = pd.DataFrame(X_test_indicators.astype(int),columns=indicator_columns,index=X_test.index)

# concatenate with the original DtaFrame
X_train = pd.concat([X_train, X_train_indicators_df], axis=1)
X_test = pd.concat([X_test, X_test_indicators_df], axis=1)

# %% [markdown]
# The **SimpleImputer** from sklearn helps to fill null values in the dataset. Since these machines are different an assumption is that the conditions represented by different features in the dataset do not apply to them hence the `fill_value` of 0

# %%
from sklearn.impute import SimpleImputer

#Impute missing values using simple imputer
imputer = SimpleImputer(strategy='constant', fill_value=0)
X_train_imputed = imputer.fit_transform(columns_to_be_imputed_train)
X_test_imputed = imputer.transform(columns_to_be_imputed_test)

X_train_imputed_df = pd.DataFrame(X_train_imputed,columns=columns_to_be_imputed_train.columns,index=X_train.index)
X_test_imputed_df = pd.DataFrame(X_test_imputed,columns=columns_to_be_imputed_test.columns,index=X_test.index)

X_train[columns_to_be_imputed_train.columns] = X_train_imputed_df
X_test[columns_to_be_imputed_test.columns] = X_test_imputed_df

X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125000 entries, 10471 to 368276
# Data columns (total 56 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Operational_Hours                   125000 non-null  int64
#  1   Temperature_C                       125000 non-null  float64
#  2   Vibration_mms                       125000 non-null  float64
#  3   Sound_dB                            125000 non-null  float64
#  4   Oil_Level_pct                       125000 non-null  float64
#  5   Coolant_Level_pct                   125000 non-null  float64
#  6   Power_Consumption_kW                125000 non-null  float64
#  7   Last_Maintenance_Days_Ago           125000 non-null  int64
#  8   Maintenance_History_Count           125000 non-null  int64
#  9   Failure_History_Count               125000 non-null  int64
#  10  AI_Supervision                      125000 non-null  int32
#  11  Error_Codes_Last_30_Days            125000 non-null  int64
#  12  Remaining_Useful_Life_days          125000 non-null  float64
#  13  Laser_Intensity                     125000 non-null  float64
#  14  Hydraulic_Pressure_bar              125000 non-null  float64
#  15  Coolant_Flow_L_min                  125000 non-null  float64
#  16  Heat_Index                          125000 non-null  float64
#  17  AI_Override_Events                  125000 non-null  int64
#  18  Machine_Age                         125000 non-null  int64
#  19  Machine_Type_3D_Printer             125000 non-null  float64
#  20  Machine_Type_AGV                    125000 non-null  float64
#  21  Machine_Type_Automated_Screwdriver  125000 non-null  float64
#  22  Machine_Type_Boiler                 125000 non-null  float64
#  23  Machine_Type_CMM                    125000 non-null  float64
#  24  Machine_Type_CNC_Lathe              125000 non-null  float64
#  25  Machine_Type_CNC_Mill               125000 non-null  float64
#  26  Machine_Type_Carton_Former          125000 non-null  float64
#  27  Machine_Type_Compressor             125000 non-null  float64
#  28  Machine_Type_Conveyor_Belt          125000 non-null  float64
#  29  Machine_Type_Crane                  125000 non-null  float64
#  30  Machine_Type_Dryer                  125000 non-null  float64
#  31  Machine_Type_Forklift_Electric      125000 non-null  float64
#  32  Machine_Type_Furnace                125000 non-null  float64
#  33  Machine_Type_Grinder                125000 non-null  float64
#  34  Machine_Type_Heat_Exchanger         125000 non-null  float64
#  35  Machine_Type_Hydraulic_Press        125000 non-null  float64
#  36  Machine_Type_Industrial_Chiller     125000 non-null  float64
#  37  Machine_Type_Injection_Molder       125000 non-null  float64
#  38  Machine_Type_Labeler                125000 non-null  float64
#  39  Machine_Type_Laser_Cutter           125000 non-null  float64
#  40  Machine_Type_Mixer                  125000 non-null  float64
#  41  Machine_Type_Palletizer             125000 non-null  float64
#  42  Machine_Type_Pick_and_Place         125000 non-null  float64
#  43  Machine_Type_Press_Brake            125000 non-null  float64
#  44  Machine_Type_Pump                   125000 non-null  float64
#  45  Machine_Type_Robot_Arm              125000 non-null  float64
#  46  Machine_Type_Shrink_Wrapper         125000 non-null  float64
#  47  Machine_Type_Shuttle_System         125000 non-null  float64
#  48  Machine_Type_Vacuum_Packer          125000 non-null  float64
#  49  Machine_Type_Valve_Controller       125000 non-null  float64
#  50  Machine_Type_Vision_System          125000 non-null  float64
#  51  Machine_Type_XRay_Inspector         125000 non-null  float64
#  52  Laser_Intensity_Missing             125000 non-null  int32
#  53  Hydraulic_Pressure_bar_Missing      125000 non-null  int32
#  54  Coolant_Flow_L_min_Missing          125000 non-null  int32
#  55  Heat_Index_Missing                  125000 non-null  int32
# dtypes: float64(44), int32(5), int64(7)
# memory usage: 52.0 MB

# %% [markdown]
# The test sample shows that all datatypes are now numbers so we can scale now
#
# Scaling of the data using the **StandardScaler** .Put all data values between 0 and 1.This preprocessing method will only be for logistic regression classification

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_logistic = pd.DataFrame(X_train_scaled,columns=X_train.columns,index=X_train.index)
X_test_logistic = pd.DataFrame(X_test_scaled,columns=X_test.columns,index=X_test.index)
#preview
X_train_logistic.head(5)
# Out:
#         Operational_Hours  Temperature_C  Vibration_mms  Sound_dB  \
# 11509           -1.617163      -1.198423       0.649333  1.670995
# 238921          -0.608756       1.681227       0.452971 -1.565244
# 272103          -1.523566      -0.445356       0.068260 -0.008648
# 60521            0.535354      -1.376360      -0.202239  0.194430
# 71915            1.460309       0.393681      -0.210254  1.091773
#
#         Oil_Level_pct  Coolant_Level_pct  Power_Consumption_kW  \
# 11509       -1.559706          -0.417893             -0.473389
# 238921      -0.233416           0.203156              1.060638
# 272103       1.622010           0.583047              0.799966
# 60521       -0.562468           1.326837              0.565299
# 71915        1.562038           0.347074              0.315504
#
#         Last_Maintenance_Days_Ago  Maintenance_History_Count  \
# 11509                   -1.385668                   0.446532
# 238921                   1.609150                   0.893341
# 272103                   0.708809                  -0.893897
# 60521                    1.694445                  -1.340706
# 71915                    1.703922                  -0.447087
#
#         Failure_History_Count  ...  Machine_Type_Shrink_Wrapper  \
# 11509               -0.000278  ...                    -0.175331
# 238921              -0.708208  ...                    -0.175331
# 272103              -0.000278  ...                    -0.175331
# 60521               -0.000278  ...                    -0.175331
# 71915                0.707653  ...                    -0.175331
#
#         Machine_Type_Shuttle_System  Machine_Type_Vacuum_Packer  \
# 11509                     -0.178592                   -0.176563
# 238921                    -0.178592                   -0.176563
# 272103                    -0.178592                   -0.176563
# 60521                     -0.178592                   -0.176563
# 71915                     -0.178592                   -0.176563
#
#         Machine_Type_Valve_Controller  Machine_Type_Vision_System  \
# 11509                       -0.177012                    -0.17674
# 238921                      -0.177012                    -0.17674
# 272103                      -0.177012                    -0.17674
# 60521                       -0.177012                    -0.17674
# 71915                       -0.177012                    -0.17674
#
#         Machine_Type_XRay_Inspector  Laser_Intensity_Missing  \
# 11509                     -0.175976                 0.177132
# 238921                    -0.175976                 0.177132
# 272103                    -0.175976                 0.177132
# 60521                     -0.175976                 0.177132
# 71915                     -0.175976                 0.177132
#
#         Hydraulic_Pressure_bar_Missing  Coolant_Flow_L_min_Missing  \
# 11509                         0.254135                   -3.157233
# 238921                       -3.934910                    0.316733
# 272103                        0.254135                   -3.157233
# 60521                        -3.934910                    0.316733
# 71915                         0.254135                    0.316733
#
#         Heat_Index_Missing
# 11509             0.315723
# 238921            0.315723
# 272103            0.315723
# 60521             0.315723
# 71915             0.315723
#
# [5 rows x 56 columns]

# %% [markdown]
# **SMOTE** library helps deal with class imbalances.For our case the minority is that the few machines will fail in the next 7 days.
# This is only done for the training subset

# %%
#First install the imblearn library
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (from imblearn) (0.7.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (from imbalanced-learn->imblearn) (0.17.0)
# Requirement already satisfied: scikit-learn>=0.23 in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (from imbalanced-learn->imblearn) (0.23.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (from imbalanced-learn->imblearn) (1.5.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (from imbalanced-learn->imblearn) (1.18.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kelvin\anaconda3\envs\learn-env\lib\site-packages (from scikit-learn>=0.23->imbalanced-learn->imblearn) (2.1.0)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_logistic, y_train_logistic = smote.fit_resample(X_train_logistic, y_train)
X_train_logistic.shape
# Out:
# (704952, 56)

# %% [markdown]
# ## 3. Modeling
#
#
# Two supervised machine learning algorithms were employed to classify whether a machine is likely to fail within the next 7 days:
#
# - **Logistic Regression**
#    The model was trained on the SMOTE-balanced dataset, and hyperparameters such as regularization strength (`C`) and class weights were tuned to see effect on perfomance.
#
# - **Decision Tree Classifier**
#   Different hyperparameters were played with to check perfomance
#
# Both models were trained using the same preprocessed dataset to ensure fair comparison. Evaluation was done using metrics such as Accuracy, F1-Score for the minority class, and AUC (Area Under the ROC Curve), providing a comprehensive understanding of model performance.

# %% [markdown]
# ###  a) Logistic Regression model
#
# For our first model we will use the vanilla version of Logistic Regression

# %%
#baseline model
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=42,class_weight='balanced')
lr.fit(X_train_logistic, y_train_logistic)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
from sklearn.metrics import classification_report, auc,accuracy_score,roc_curve, RocCurveDisplay

y_pred = lr.predict(X_test_logistic)
y_scores = lr.predict_proba(X_test_logistic)[:, 1]
print('accuracy score :{}'.format(accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# accuracy score :0.993536
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    117492
#            1       0.90      1.00      0.95      7508
#
#     accuracy                           0.99    125000
#    macro avg       0.95      1.00      0.97    125000
# weighted avg       0.99      0.99      0.99    125000

# %%
#visualization of the ROC curve
#probabilities for the positive class (label 1)

fpr, tpr, thresholds = roc_curve(y_test, y_scores)
RocCurveDisplay(fpr=fpr, tpr=tpr).plot()
plt.title('ROC Curve')
plt.show()

print("AUC:", auc(fpr, tpr))
# Out:
# AUC: 0.9999822203063744

# %%
#Look at the parameters for the dafault model
lr.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': 'balanced',
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 42,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
#We are going to play with a few of this hyper parameters to see their effect on model

C_values = [0.001, 0.01, 0.1, 1, 10, 100]

plt.figure(figsize=(10, 7))


for c in C_values:
    model = LogisticRegression(C=c, class_weight='balanced', random_state=42)
    model.fit(X_train_logistic, y_train_logistic)

    
    y_scores = model.predict_proba(X_test_scaled)[:, 1]

    #ROC curve and AUC
    fpr, tpr, thresholds = roc_curve(y_test, y_scores)
    auc_score = auc(fpr, tpr)

    #pot ROC curve
    plt.plot(fpr, tpr, label=f'C={c} (AUC={auc_score:.4f})')


plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.title('ROC Curves for Different C Values in Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Kelvin\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
###conclude

# %% [markdown]
# ### b) Decision Trees
# lets use the Vanilla version of this model - just with defaults arguments
#
# The scaling and SMOTE transformations were important for the logistic regression because it is a linear model however for decison trees we will use versions of data without this transformations - `X_train` `y_train`,`X_test` and `y_test`

# %%
#preview X _train
X_train.head()
# Out:
#         Operational_Hours  Temperature_C  Vibration_mms  Sound_dB  \
# 11509                3325          41.99          13.23     91.70
# 238921              32447          85.20          12.25     59.35
# 272103               6028          53.29          10.33     74.91
# 60521               65488          39.32           8.98     76.94
# 71915               92200          65.88           8.94     85.91
#
#         Oil_Level_pct  Coolant_Level_pct  Power_Consumption_kW  \
# 11509           40.05              54.46                112.08
# 238921          65.04              68.83                234.78
# 272103         100.00              77.62                213.93
# 60521           58.84              94.83                195.16
# 71915           98.87              72.16                175.18
#
#         Last_Maintenance_Days_Ago  Maintenance_History_Count  \
# 11509                          36                          6
# 238921                        352                          7
# 272103                        257                          3
# 60521                         361                          2
# 71915                         362                          4
#
#         Failure_History_Count  ...  Machine_Type_Shrink_Wrapper  \
# 11509                       2  ...                          0.0
# 238921                      1  ...                          0.0
# 272103                      2  ...                          0.0
# 60521                       2  ...                          0.0
# 71915                       3  ...                          0.0
#
#         Machine_Type_Shuttle_System  Machine_Type_Vacuum_Packer  \
# 11509                           0.0                         0.0
# 238921                          0.0                         0.0
# 272103                          0.0                         0.0
# 60521                           0.0                         0.0
# 71915                           0.0                         0.0
#
#         Machine_Type_Valve_Controller  Machine_Type_Vision_System  \
# 11509                             0.0                         0.0
# 238921                            0.0                         0.0
# 272103                            0.0                         0.0
# 60521                             0.0                         0.0
# 71915                             0.0                         0.0
#
#         Machine_Type_XRay_Inspector  Laser_Intensity_Missing  \
# 11509                           0.0                        1
# 238921                          0.0                        1
# 272103                          0.0                        1
# 60521                           0.0                        1
# 71915                           0.0                        1
#
#         Hydraulic_Pressure_bar_Missing  Coolant_Flow_L_min_Missing  \
# 11509                                1                           0
# 238921                               0                           1
# 272103                               1                           0
# 60521                                0                           1
# 71915                                1                           1
#
#         Heat_Index_Missing
# 11509                    1
# 238921                   1
# 272103                   1
# 60521                    1
# 71915                    1
#
# [5 rows x 56 columns]

# %%
from sklearn.tree import DecisionTreeClassifier


dt = DecisionTreeClassifier(random_state = 42)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#The perfomance of the vanilla model

# Make predictions using test set 
y_pred = dt.predict(X_test)

# Check the AUC of predictions
fpr_gini, tpr_gini, thresholds = roc_curve(y_test,y_pred)
roc_auc = auc(fpr_gini,tpr_gini)
roc_auc
# Out:
# 1.0

# %%
dt.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': 42,
#  'splitter': 'best'}

# %%
#lets use our criterion to be entropy
dt_entropy = DecisionTreeClassifier(criterion='entropy',random_state = 42)
dt_entropy.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
# Check the AUC of predictions
fpr_entropy, tpr_entropy, thresholds = roc_curve(y_test,y_pred)
roc_auc = auc(fpr_entropy,tpr_entropy)
roc_auc
# Out:
# 1.0

# %%
#playing with hyperparameters
#maxdepth
# Identify the optimal tree depth for given data
max_depth = list(range(1,33))
auc_train_list =[]
auc_test_list = []

for depth in max_depth:
    dt_c = DecisionTreeClassifier(max_depth = depth,random_state = 42)
    dt_c.fit(X_train,y_train)
    
    y_prd_train= dt_c.predict(X_train)
    y_prd_test = dt_c.predict(X_test)
    
    fpr_train,tpr_train,thresholds_train= roc_curve(y_train,y_prd_train)
    fpr_test,tpr_test,thresholds_test= roc_curve(y_test,y_prd_test)
    
    auc_score_train = auc(fpr_train,tpr_train)
    auc_score_test = auc(fpr_test,tpr_test)
    auc_train_list.append(auc_score_train)
    auc_test_list.append(auc_score_test)

plt.figure(figsize=(10, 8))
    
plt.plot(max_depth, auc_train_list, label='Train AUC', marker='o')
plt.plot(max_depth, auc_test_list, label='Test AUC', marker='o')
plt.xlabel('Max_depth range')
plt.ylabel('AUC scores')
plt.title('auc perfomance vs max_depth')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Identify the optimal min-samples-split for given data
min_sample_splits = np.arange(0.1, 1.0, 0.1)

train_auc = []
test_auc = []

# Loop through each value
for val in min_sample_splits:
    clf = DecisionTreeClassifier(min_samples_split=val, random_state=42)
    clf.fit(X_train_logistic, y_train_logistic)
    
    # Predictions
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    
    fpr_train,tpr_train,thresholds_train = roc_curve(y_train, y_train_pred)
    fpr_test,tpr_test,thresholds_test = roc_curve(y_test, y_test_pred)
    
    # Compute AUC
    train_auc.append(auc(fpr_train,tpr_train))
    test_auc.append(auc(fpr_test, tpr_test))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(min_sample_splits, train_auc, label='Train AUC', marker='o')
plt.plot(min_sample_splits, test_auc, label='Test AUC', marker='o')
plt.xlabel('min_samples_split (as fraction)')
plt.ylabel('AUC Score')
plt.title('AUC vs min_samples_split')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusion
#
# This project focuses on building a classification model to predict machine failures within the next 7 days using a synthetic Industrial IoT dataset. The goal is to support **predictive maintenance**, allowing industries to anticipate failures and carry out proactive interventions—ultimately reducing unplanned downtime and maintenance costs.
#
# ###  Data Preprocessing
#
# The data was thoroughly preprocessed through the following steps:
#
# - Handling missing values using `SimpleImputer` and `MissingIndicator`
# - Encoding categorical variables with `OneHotEncoder`
# - Scaling numerical features where applicable
# - Addressing class imbalance using the `SMOTE` algorithm
#
# Two machine learning models were trained and evaluated: **Logistic Regression** and **Decision Tree Classifier**.
#
# ---
#
# ###  Model Evaluation
#
# #### Logistic Regression:
# - **AUC Score**: [Insert AUC Score Here]
# - **Accuracy**: [Insert Accuracy Here]
# - **F1-score (Minority class)**: [Insert F1 Here]
#
# #### Decision Tree:
# - **AUC Score**: [Insert AUC Score Here]
# - **Accuracy**: [Insert Accuracy Here]
# - **F1-score (Minority class)**: [Insert F1 Here]
#
# ---
#
# ###  Observations
#
# Both models demonstrated strong performance, particularly in terms of AUC. However, caution is warranted when interpreting these results. The original dataset exhibited **significant class imbalance**, and while SMOTE was applied to mitigate this issue, the potential for **overfitting**—especially with the Decision Tree model—remains.
#
# Furthermore, some features (e.g., `Laser_Intensity`, `Hydraulic_Pressure_bar`) are **machine-specific** and contain a high proportion of missing values. Building **machine-type-specific models** in future iterations may improve predictive accuracy and interpretability.
#
# ---
#
# ###  Recommendations for Future Work
#
# - Develop separate models tailored to specific machine types
# - Explore advanced algorithms such as Random Forest or XGBoost for better generalization
# - Consider implementing time-aware cross-validation if temporal features (e.g., timestamps or installation year) are available
